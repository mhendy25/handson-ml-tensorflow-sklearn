# %%
from sklearn.datasets import fetch_openml

mnist = fetch_openml('mnist_784', as_frame=False)
X_train, y_train = mnist.data[:60_000], mnist.target[:60_000]
X_test, y_test = mnist.data[60_000:], mnist.target[60_000:]

# %%
from sklearn.decomposition import PCA 

pca  = PCA()
pca.fit(X_train)
# Out:
# PCA()

# %%
import numpy as np 
cumsum = np.cumsum(pca.explained_variance_ratio_)
cumsum
# Out:
# array([0.09704664, 0.16800588, 0.22969677, 0.28359097, 0.33227894,
#        0.37540125, 0.40812055, 0.4369595 , 0.4645798 , 0.4881498 ,
#        0.5092417 , 0.52947161, 0.54662979, 0.56355091, 0.57933732,
#        0.59416685, 0.60741246, 0.62018143, 0.63205406, 0.6435809 ,
#        0.65424256, 0.66430969, 0.67384542, 0.68297086, 0.69180491,
#        0.7001981 , 0.70832389, 0.71618755, 0.72363488, 0.73054347,
#        0.73712441, 0.74360589, 0.74963204, 0.75549786, 0.76119807,
#        0.76663435, 0.77169222, 0.7765708 , 0.7813851 , 0.78610776,
#        0.79067523, 0.79512359, 0.7993086 , 0.80329076, 0.8071405 ,
#        0.81089154, 0.81451162, 0.81802754, 0.82142812, 0.82464686,
#        0.82783703, 0.83096508, 0.83392491, 0.83681446, 0.83965576,
#        0.84237012, 0.84506533, 0.84765006, 0.85018776, 0.85263557,
#        0.85504063, 0.85743326, 0.85973735, 0.86195267, 0.86408988,
#        0.86616213, 0.86819256, 0.87016038, 0.87208891, 0.87397523,
# ...

# %%
np.argmax(cumsum >= 0.95) # 154 dimensions needed to preserve 95% of the original variance
# Out:
# 153

# %%
cumsum[152], cumsum[153]
# Out:
# (0.9497456393815948, 0.9501960192613033)

# %%
X = np.random.randn(100000,1000)
pca = PCA(n_components=0.95)
X_reduced = pca.fit_transform(X)

# %%
pca.n_components_
# Out:
# 940

# %% [markdown]
# - Testing `Random Forest` and `SGD` with and without PCA

# %%
from sklearn.datasets import fetch_openml

mnist = fetch_openml('mnist_784', as_frame=False)
X_train, y_train = mnist.data[:60_000], mnist.target[:60_000]
X_test, y_test = mnist.data[60_000:], mnist.target[60_000:]

# %%
from sklearn.ensemble import RandomForestClassifier

rnd_forest_clf = RandomForestClassifier(random_state=42)
rnd_forest_clf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
rnd_forest_clf.score(X_test, y_test)
# Out:
# 0.9691

# %%
pca = PCA(n_components=0.95)
X_train_reduced = pca.fit_transform(X_train)

# %%
pca_rnd_forest_clf = RandomForestClassifier(random_state=42)
pca_rnd_forest_clf.fit(X_train_reduced, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
pca.n_components_
# Out:
# 154

# %%
X_test_reduced = pca.transform(X_test) # not fit transform!

# %%
pca_rnd_forest_clf.score(X_test_reduced, y_test)
# Out:
# 0.9487

# %%
from sklearn.linear_model import SGDClassifier
sgd_clf = SGDClassifier(random_state=42)
sgd_clf.fit(X_train, y_train)
# Out:
# SGDClassifier(random_state=42)

# %%
sgd_clf.score(X_test, y_test)
# Out:
# 0.874

# %%
sgd_clf.fit(X_train_reduced, y_train)
# Out:
# SGDClassifier(random_state=42)

# %%
sgd_clf.score(X_test_reduced, y_test)
# Out:
# 0.8959

# %% [markdown]
# - Takeaway: PCA could help speedup training and potentially boost the performance, depending on the dataset and training model
